# %% [markdown]
# <a href="https://colab.research.google.com/github/zenithrastogi2025-maker/Zenith/blob/main/airpassengers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("/mnt/data/AirPassengers.csv")

# Display first 5 rows
print(df.head())

# Display dataset information
print(df.info())

# Convert Month to datetime
df["Month"] = pd.to_datetime(df["Month"])

# Set Month as index
df.set_index("Month", inplace=True)

# Plot the number of passengers
plt.figure(figsize=(12, 5))
plt.plot(df.index, df["#Passengers"])
plt.xlabel("Month")
plt.ylabel("Number of Passengers")
plt.title("Air Passengers Over Time")
plt.show()
